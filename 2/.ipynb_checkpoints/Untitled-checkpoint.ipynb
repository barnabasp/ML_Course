# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1

# %%
df = pd.read_csv('02_dataset_worldbank_jobs_2016.tsv',delimiter='\t')

# %%
df = df.dropna().reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36022 entries, 0 to 36021
# Data columns (total 6 columns):
# index            36022 non-null int64
# Country Name     36022 non-null object
# Country Code     36022 non-null object
# Series Name      36022 non-null object
# Series Code      36022 non-null object
# 2016 [YR2016]    36022 non-null object
# dtypes: int64(1), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# after investigation, found out that missing data is represented by ".."

# %%
df[df["2016 [YR2016]"] == ".."]
# Out:
#        index Country Name Country Code  \
# 23        23  Afghanistan          AFG
# 24        24  Afghanistan          AFG
# 45        45  Afghanistan          AFG
# 50        50  Afghanistan          AFG
# 51        51  Afghanistan          AFG
# ...      ...          ...          ...
# 36003  36003     Zimbabwe          ZWE
# 36004  36004     Zimbabwe          ZWE
# 36005  36005     Zimbabwe          ZWE
# 36006  36006     Zimbabwe          ZWE
# 36007  36007     Zimbabwe          ZWE
#
#                                              Series Name        Series Code  \
# 23     Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 24           Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 45               Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN
# 50                      GINI index (World Bank estimate)        SI.POV.GINI
# 51     Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# ...                                                  ...                ...
# 36003  Unemployment with advanced education, female (...  SL.UEM.ADVN.FE.ZS
# 36004  Unemployment with advanced education, male (% ...  SL.UEM.ADVN.MA.ZS
# 36005  Unemployment with intermediate education (% of...     SL.UEM.INTM.ZS
# 36006  Unemployment with intermediate education, fema...  SL.UEM.INTM.FE.ZS
# 36007  Unemployment with intermediate education, male...  SL.UEM.INTM.MA.ZS
#
#       2016 [YR2016]
# 23               ..
# 24               ..
# 45               ..
# 50               ..
# 51               ..
# ...             ...
# 36003            ..
# 36004            ..
# 36005            ..
# 36006            ..
# 36007            ..
#
# [12908 rows x 6 columns]

# %%
pivoted_df = df.pivot(index='Country Code', columns='Series Code', values='2016 [YR2016]')
pivoted_df
# Out:
# Series Code  BM.KLT.DINV.WD.GD.ZS BM.TRF.PWKR.CD.DT BX.KLT.DINV.WD.GD.ZS  \
# Country Code
# ABW                            ..  71743528.4916201                   ..
# AFG           -0.0758945950132622  118216397.348387    0.480709517928724
# AGO              2.88213834819657     1176110313.56     4.30516364069576
# ALB            0.0592091751160614  147128144.977279     8.78673446886916
# AND                            ..                ..                   ..
# ...                           ...               ...                  ...
# XKX             0.700565756032146  66734849.5572601     3.62936692691499
# YEM             0.191606931501499                ..    -3.08016185948595
# ZAF               1.5182706815113  896870556.213536    0.749015048767685
# ZMB             0.843339723083547  63405836.4378634     3.16307184259788
# ZWE             0.200560044655702  13844871.1232992     2.06386661053657
#
# Series Code     BX.TRF.PWKR.CD CM.MKT.LCAP.GD.ZS    EG.ELC.ACCS.ZS  \
# Country Code
# ABW           5787158.10055866                ..  95.5701446533203
# AFG           277483515.060727                ..  84.1371383666992
# AGO                 3988048.38                ..  40.5206069946289
# ALB           996001354.462477                ..               100
# AND                         ..                ..               100
# ...                        ...               ...               ...
# XKX           764488042.103565                ..               100
# YEM                         ..                ..  71.6423492431641
# ZAF                         ..  321.649882279292              84.2
# ZMB           38464441.0005245                ..  27.2193374633789
# ZWE            1853078310.3645                ..  38.1451377868652
#
# Series Code  EG.USE.ELEC.KH.PC       EN.POP.DNST    FB.ATM.TOTL.P5  \
# Country Code
# ABW                         ..  582.344444444444  126.019533027619
# AFG                         ..  53.0834053242655  1.07421538203442
# AGO                         ..  23.1117855137563                ..
# ALB                         ..  104.967189781022  33.8068122098151
# AND                         ..  164.427659574468                ..
# ...                        ...               ...               ...
# XKX                         ..  166.822816202811  38.3268809808933
# YEM                         ..  52.2457961626608                ..
# ZAF                         ..  46.1758591695587  69.2897894314741
# ZMB                         ..  22.3185541909361  11.1525244935673
# ZWE                         ..  41.7483830942226  6.01007432106493
#
# Series Code     FB.CBK.BRWR.P3  ... SP.POP.TOTL SP.RUR.TOTL SP.RUR.TOTL.ZS  \
# Country Code                    ...
# ABW                         ..  ...      104822       59547         56.808
# AFG           3.05195383587665  ...    34656032    25985093          74.98
# AGO           18.1587749690844  ...    28813463    10329915         35.851
# ALB           157.797944425991  ...     2876101     1195854         41.579
# AND                         ..  ...       77281        9082         11.752
# ...                        ...  ...         ...         ...            ...
# XKX           74.7521025414702  ...     1816200          ..             ..
# YEM                         ..  ...    27584213    17821057         64.606
# ZAF                         ..  ...    56015473    19414403         34.659
# ZMB           24.4350055350989  ...    16591390     9550336         57.562
# ZWE           218.826911655182  ...    16150362    10934441         67.704
#
# Series Code  SP.URB.TOTL SP.URB.TOTL.IN.ZS TM.VAL.ICTG.ZS.UN  \
# Country Code
# ABW                45275            43.192      4.9181484453
# AFG              8670939             25.02       0.262056153
# AGO             18483548            64.149                ..
# ALB              1680247            58.421      2.9414365045
# AND                68199            88.248                ..
# ...                  ...               ...               ...
# XKX                   ..                ..                ..
# YEM              9763156            35.394                ..
# ZAF             36601070            65.341      8.6167994168
# ZMB              7041054            42.438                ..
# ZWE              5215921            32.296      3.7287650761
#
# Series Code  TX.QTY.MRCH.XD.WD  TX.VAL.FUEL.ZS.UN TX.VAL.MRCH.XD.WD  \
# Country Code
# ABW                5.797836151  0.105049448266972       11.88815623
# AFG                185.0455137                 ..       434.3793696
# AGO                223.0964467                 ..       344.7317258
# ALB                556.6603641   11.1789815992628        750.385083
# AND                149.8840596                 ..       186.0462838
# ...                        ...                ...               ...
# XKX                         ..                 ..                ..
# YEM                11.12988709                 ..        24.5158127
# ZAF                156.2443961   9.98146418269729        250.445219
# ZMB                267.8411004                 ..       650.0782034
# ZWE                71.52177037  0.372328622664921       147.1310649
#
# Series Code   TX.VAL.TECH.MF.ZS
# Country Code
# ABW            3.75873566084448
# AFG                          ..
# AGO                          ..
# ALB           0.647750656841347
# AND                          ..
# ...                         ...
# XKX                          ..
# YEM                          ..
# ZAF            5.29205550382907
# ZMB                          ..
# ZWE            5.20645305938165
#
# [217 rows x 166 columns]

# %% [markdown]
# # 2

# %%
plt.figure(figsize=(30, 20))
plt.title('Missing values in countries v data series', fontsize=20)
plt.ylabel('Country Codes', fontsize=20)
plt.xlabel('Data Series', fontsize=20)
plt.imshow((pivoted_df== '..'), cmap='gist_heat')

# %%
pivoted_df.index[0]
dropped_pivot = pivoted_df.copy()

# %%
for iCntry in range(np.shape(pivoted_df)[0]):
    if(np.unique(pivoted_df.values[iCntry] == '..', return_counts=True)[1][1] >= 60):
        #drop the row which has more than or equal to 60
        dropped_pivot.drop(pivoted_df.index[iCntry], inplace=True)

# %%
dropped_pivot
# Out:
# Series Code  BM.KLT.DINV.WD.GD.ZS BM.TRF.PWKR.CD.DT BX.KLT.DINV.WD.GD.ZS  \
# Country Code
# AFG           -0.0758945950132622  118216397.348387    0.480709517928724
# ALB            0.0592091751160614  147128144.977279     8.78673446886916
# ARE              4.40039691194953                ..     2.51668651639507
# ARG             0.321978137189706  823565671.520054    0.587564212452168
# ARM             0.627751723837743  358015507.114938     3.20605773747274
# ...                           ...               ...                  ...
# WSM              1.95383604019208  18058170.8249882    0.321022637394075
# YEM             0.191606931501499                ..    -3.08016185948595
# ZAF               1.5182706815113  896870556.213536    0.749015048767685
# ZMB             0.843339723083547  63405836.4378634     3.16307184259788
# ZWE             0.200560044655702  13844871.1232992     2.06386661053657
#
# Series Code     BX.TRF.PWKR.CD CM.MKT.LCAP.GD.ZS    EG.ELC.ACCS.ZS  \
# Country Code
# AFG           277483515.060727                ..  84.1371383666992
# ALB           996001354.462477                ..               100
# ARE                         ..  62.0183337934548               100
# ARG           352639302.322353  11.4625324986418               100
# ARM             608660930.8121                ..               100
# ...                        ...               ...               ...
# WSM           132604667.983912                ..               100
# YEM                         ..                ..  71.6423492431641
# ZAF                         ..  321.649882279292              84.2
# ZMB           38464441.0005245                ..  27.2193374633789
# ZWE            1853078310.3645                ..  38.1451377868652
#
# Series Code  EG.USE.ELEC.KH.PC       EN.POP.DNST    FB.ATM.TOTL.P5  \
# Country Code
# AFG                         ..  53.0834053242655  1.07421538203442
# ALB                         ..  104.967189781022  33.8068122098151
# ARE                         ..  110.880526315789   65.683037189653
# ARG                         ..  16.0220668033281  60.1037381390599
# ARM                         ..  102.733263083948   61.139439335971
# ...                        ...               ...               ...
# WSM                         ..  68.9487632508834  47.0767757278638
# YEM                         ..  52.2457961626608                ..
# ZAF                         ..  46.1758591695587  69.2897894314741
# ZMB                         ..  22.3185541909361  11.1525244935673
# ZWE                         ..  41.7483830942226  6.01007432106493
#
# Series Code     FB.CBK.BRWR.P3  ... SP.POP.TOTL SP.RUR.TOTL SP.RUR.TOTL.ZS  \
# Country Code                    ...
# AFG           3.05195383587665  ...    34656032    25985093          74.98
# ALB           157.797944425991  ...     2876101     1195854         41.579
# ARE                         ..  ...     9269612     1300990         14.035
# ARG           393.196311620749  ...    43847430     3671345          8.373
# ARM                         ..  ...     2924816     1079784         36.918
# ...                        ...  ...         ...         ...            ...
# WSM           123.966137188218  ...      195125      158674         81.319
# YEM                         ..  ...    27584213    17821057         64.606
# ZAF                         ..  ...    56015473    19414403         34.659
# ZMB           24.4350055350989  ...    16591390     9550336         57.562
# ZWE           218.826911655182  ...    16150362    10934441         67.704
#
# Series Code  SP.URB.TOTL SP.URB.TOTL.IN.ZS TM.VAL.ICTG.ZS.UN  \
# Country Code
# AFG              8670939             25.02       0.262056153
# ALB              1680247            58.421      2.9414365045
# ARE              7968622            85.965      5.5351682242
# ARG             40176085            91.627       8.478811845
# ARM              1845032            63.082      4.8953531596
# ...                  ...               ...               ...
# WSM                36451            18.681      4.6171483859
# YEM              9763156            35.394                ..
# ZAF             36601070            65.341      8.6167994168
# ZMB              7041054            42.438                ..
# ZWE              5215921            32.296      3.7287650761
#
# Series Code  TX.QTY.MRCH.XD.WD  TX.VAL.FUEL.ZS.UN TX.VAL.MRCH.XD.WD  \
# Country Code
# AFG                185.0455137                 ..       434.3793696
# ALB                556.6603641   11.1789815992628        750.385083
# ARE                132.6684666   20.2288541979265       533.5579454
# ARG                124.3660983   2.53245061230712       219.1746707
# ARM                355.6565539    3.8219981779404       609.0074779
# ...                        ...                ...               ...
# WSM                65.79322959   21.4788157608196       86.21538462
# YEM                11.12988709                 ..        24.5158127
# ZAF                156.2443961   9.98146418269729        250.445219
# ZMB                267.8411004                 ..       650.0782034
# ZWE                71.52177037  0.372328622664921       147.1310649
#
# Series Code   TX.VAL.TECH.MF.ZS
# Country Code
# AFG                          ..
# ALB           0.647750656841347
# ARE            2.32146635303879
# ARG            8.79281472735163
# ARM            5.93860928912599
# ...                         ...
# WSM           0.852263362981328
# YEM                          ..
# ZAF            5.29205550382907
# ZMB                          ..
# ZWE            5.20645305938165
#
# [158 rows x 166 columns]

# %%
dropped_pivot.drop(columns=dropped_pivot.columns[0])
# Out:
# Series Code  BM.TRF.PWKR.CD.DT BX.KLT.DINV.WD.GD.ZS    BX.TRF.PWKR.CD  \
# Country Code
# AFG           118216397.348387    0.480709517928724  277483515.060727
# ALB           147128144.977279     8.78673446886916  996001354.462477
# ARE                         ..     2.51668651639507                ..
# ARG           823565671.520054    0.587564212452168  352639302.322353
# ARM           358015507.114938     3.20605773747274    608660930.8121
# ...                        ...                  ...               ...
# WSM           18058170.8249882    0.321022637394075  132604667.983912
# YEM                         ..    -3.08016185948595                ..
# ZAF           896870556.213536    0.749015048767685                ..
# ZMB           63405836.4378634     3.16307184259788  38464441.0005245
# ZWE           13844871.1232992     2.06386661053657   1853078310.3645
#
# Series Code  CM.MKT.LCAP.GD.ZS    EG.ELC.ACCS.ZS EG.USE.ELEC.KH.PC  \
# Country Code
# AFG                         ..  84.1371383666992                ..
# ALB                         ..               100                ..
# ARE           62.0183337934548               100                ..
# ARG           11.4625324986418               100                ..
# ARM                         ..               100                ..
# ...                        ...               ...               ...
# WSM                         ..               100                ..
# YEM                         ..  71.6423492431641                ..
# ZAF           321.649882279292              84.2                ..
# ZMB                         ..  27.2193374633789                ..
# ZWE                         ..  38.1451377868652                ..
#
# Series Code        EN.POP.DNST    FB.ATM.TOTL.P5    FB.CBK.BRWR.P3  \
# Country Code
# AFG           53.0834053242655  1.07421538203442  3.05195383587665
# ALB           104.967189781022  33.8068122098151  157.797944425991
# ARE           110.880526315789   65.683037189653                ..
# ARG           16.0220668033281  60.1037381390599  393.196311620749
# ARM           102.733263083948   61.139439335971                ..
# ...                        ...               ...               ...
# WSM           68.9487632508834  47.0767757278638  123.966137188218
# YEM           52.2457961626608                ..                ..
# ZAF           46.1758591695587  69.2897894314741                ..
# ZMB           22.3185541909361  11.1525244935673  24.4350055350989
# ZWE           41.7483830942226  6.01007432106493  218.826911655182
#
# Series Code        FP.CPI.TOTL  ... SP.POP.TOTL SP.RUR.TOTL SP.RUR.TOTL.ZS  \
# Country Code                    ...
# AFG           137.904563672559  ...    34656032    25985093          74.98
# ALB           112.834428489197  ...     2876101     1195854         41.579
# ARE           111.115725679973  ...     9269612     1300990         14.035
# ARG                         ..  ...    43847430     3671345          8.373
# ARM           123.014933984404  ...     2924816     1079784         36.918
# ...                        ...  ...         ...         ...            ...
# WSM           109.762507807415  ...      195125      158674         81.319
# YEM                         ..  ...    27584213    17821057         64.606
# ZAF           138.859306590936  ...    56015473    19414403         34.659
# ZMB           169.781989060935  ...    16591390     9550336         57.562
# ZWE           104.560626128854  ...    16150362    10934441         67.704
#
# Series Code  SP.URB.TOTL SP.URB.TOTL.IN.ZS TM.VAL.ICTG.ZS.UN  \
# Country Code
# AFG              8670939             25.02       0.262056153
# ALB              1680247            58.421      2.9414365045
# ARE              7968622            85.965      5.5351682242
# ARG             40176085            91.627       8.478811845
# ARM              1845032            63.082      4.8953531596
# ...                  ...               ...               ...
# WSM                36451            18.681      4.6171483859
# YEM              9763156            35.394                ..
# ZAF             36601070            65.341      8.6167994168
# ZMB              7041054            42.438                ..
# ZWE              5215921            32.296      3.7287650761
#
# Series Code  TX.QTY.MRCH.XD.WD  TX.VAL.FUEL.ZS.UN TX.VAL.MRCH.XD.WD  \
# Country Code
# AFG                185.0455137                 ..       434.3793696
# ALB                556.6603641   11.1789815992628        750.385083
# ARE                132.6684666   20.2288541979265       533.5579454
# ARG                124.3660983   2.53245061230712       219.1746707
# ARM                355.6565539    3.8219981779404       609.0074779
# ...                        ...                ...               ...
# WSM                65.79322959   21.4788157608196       86.21538462
# YEM                11.12988709                 ..        24.5158127
# ZAF                156.2443961   9.98146418269729        250.445219
# ZMB                267.8411004                 ..       650.0782034
# ZWE                71.52177037  0.372328622664921       147.1310649
#
# Series Code   TX.VAL.TECH.MF.ZS
# Country Code
# AFG                          ..
# ALB           0.647750656841347
# ARE            2.32146635303879
# ARG            8.79281472735163
# ARM            5.93860928912599
# ...                         ...
# WSM           0.852263362981328
# YEM                          ..
# ZAF            5.29205550382907
# ZMB                          ..
# ZWE            5.20645305938165
#
# [158 rows x 165 columns]

# %%
np.unique(dropped_pivot.values[0] == '..', return_counts=True, return_index=True)
# Out:
# (array([False,  True]), array([0, 4]), array([111,  55]))

# %%
dropped_pivot.drop(columns=dropped_pivot.columns[dropped_pivot.values[0] == '..'])
# Out:
# Series Code  BM.KLT.DINV.WD.GD.ZS BM.TRF.PWKR.CD.DT BX.KLT.DINV.WD.GD.ZS  \
# Country Code
# AFG           -0.0758945950132622  118216397.348387    0.480709517928724
# ALB            0.0592091751160614  147128144.977279     8.78673446886916
# ARE              4.40039691194953                ..     2.51668651639507
# ARG             0.321978137189706  823565671.520054    0.587564212452168
# ARM             0.627751723837743  358015507.114938     3.20605773747274
# ...                           ...               ...                  ...
# WSM              1.95383604019208  18058170.8249882    0.321022637394075
# YEM             0.191606931501499                ..    -3.08016185948595
# ZAF               1.5182706815113  896870556.213536    0.749015048767685
# ZMB             0.843339723083547  63405836.4378634     3.16307184259788
# ZWE             0.200560044655702  13844871.1232992     2.06386661053657
#
# Series Code     BX.TRF.PWKR.CD    EG.ELC.ACCS.ZS       EN.POP.DNST  \
# Country Code
# AFG           277483515.060727  84.1371383666992  53.0834053242655
# ALB           996001354.462477               100  104.967189781022
# ARE                         ..               100  110.880526315789
# ARG           352639302.322353               100  16.0220668033281
# ARM             608660930.8121               100  102.733263083948
# ...                        ...               ...               ...
# WSM           132604667.983912               100  68.9487632508834
# YEM                         ..  71.6423492431641  52.2457961626608
# ZAF                         ..              84.2  46.1758591695587
# ZMB           38464441.0005245  27.2193374633789  22.3185541909361
# ZWE            1853078310.3645  38.1451377868652  41.7483830942226
#
# Series Code     FB.ATM.TOTL.P5    FB.CBK.BRWR.P3       FP.CPI.TOTL  \
# Country Code
# AFG           1.07421538203442  3.05195383587665  137.904563672559
# ALB           33.8068122098151  157.797944425991  112.834428489197
# ARE            65.683037189653                ..  111.115725679973
# ARG           60.1037381390599  393.196311620749                ..
# ARM            61.139439335971                ..  123.014933984404
# ...                        ...               ...               ...
# WSM           47.0767757278638  123.966137188218  109.762507807415
# YEM                         ..                ..                ..
# ZAF           69.2897894314741                ..  138.859306590936
# ZMB           11.1525244935673  24.4350055350989  169.781989060935
# ZWE           6.01007432106493  218.826911655182  104.560626128854
#
# Series Code  FP.CPI.TOTL.ZG  ...       SP.POP.DPND         SP.POP.GROW  \
# Country Code                 ...
# AFG             2.169452176  ...  86.5709321507136     2.6891634730922
# ALB             1.282798834  ...  44.0015401014685  -0.159880412127734
# ARE             1.617876882  ...  17.6081783608388    1.25175905246942
# ARG                      ..  ...  56.5422464275751   0.984741905647839
# ARM            -1.271210454  ...  44.8949433189816   0.269302288175516
# ...                     ...  ...               ...                 ...
# WSM              1.30385728  ...  73.3750944066818   0.702526006807934
# YEM                      ..  ...  75.9001725764795    2.45150204297636
# ZAF               6.3262638  ...  52.4085780041956    1.30137401321457
# ZMB             17.86996005  ...  90.7796634648112    3.00281551523404
# ZWE             -1.55978908  ...  79.1953035239659     2.3360695495183
#
# Series Code  SP.POP.TOTL SP.RUR.TOTL SP.RUR.TOTL.ZS SP.URB.TOTL  \
# Country Code
# AFG             34656032    25985093          74.98     8670939
# ALB              2876101     1195854         41.579     1680247
# ARE              9269612     1300990         14.035     7968622
# ARG             43847430     3671345          8.373    40176085
# ARM              2924816     1079784         36.918     1845032
# ...                  ...         ...            ...         ...
# WSM               195125      158674         81.319       36451
# YEM             27584213    17821057         64.606     9763156
# ZAF             56015473    19414403         34.659    36601070
# ZMB             16591390     9550336         57.562     7041054
# ZWE             16150362    10934441         67.704     5215921
#
# Series Code  SP.URB.TOTL.IN.ZS TM.VAL.ICTG.ZS.UN TX.QTY.MRCH.XD.WD  \
# Country Code
# AFG                      25.02       0.262056153       185.0455137
# ALB                     58.421      2.9414365045       556.6603641
# ARE                     85.965      5.5351682242       132.6684666
# ARG                     91.627       8.478811845       124.3660983
# ARM                     63.082      4.8953531596       355.6565539
# ...                        ...               ...               ...
# WSM                     18.681      4.6171483859       65.79322959
# YEM                     35.394                ..       11.12988709
# ZAF                     65.341      8.6167994168       156.2443961
# ZMB                     42.438                ..       267.8411004
# ZWE                     32.296      3.7287650761       71.52177037
#
# Series Code  TX.VAL.MRCH.XD.WD
# Country Code
# AFG                434.3793696
# ALB                 750.385083
# ARE                533.5579454
# ARG                219.1746707
# ARM                609.0074779
# ...                        ...
# WSM                86.21538462
# YEM                 24.5158127
# ZAF                 250.445219
# ZMB                650.0782034
# ZWE                147.1310649
#
# [158 rows x 111 columns]

# %%
for iCntry in range(np.shape(dropped_pivot)[0]):
    dropped_pivot.drop(columns=dropped_pivot.columns[dropped_pivot.values[iCntry] == '..'],inplace=True)

# %% [markdown]
# Check if our method was OK

# %%
plt.figure(figsize=(30, 20))
plt.title('Missing values in countries v data series', fontsize=20)
plt.ylabel('Country Codes', fontsize=20)
plt.xlabel('Data Series', fontsize=20)
plt.imshow((dropped_pivot== '..'), cmap='gist_heat')

# %%
dropped_pivot.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, AFG to ZWE
# Columns: 62 entries, BX.KLT.DINV.WD.GD.ZS to SP.URB.TOTL.IN.ZS
# dtypes: object(62)
# memory usage: 77.8+ KB

# %%
for iSerie in range(np.shape(dropped_pivot.columns)[0]):
    print(df[df['Series Code'] == dropped_pivot.columns[iSerie]]['Series Name'].values[0])
# Out:
# Foreign direct investment, net inflows (% of GDP)
# Access to electricity (% of population)
# Population density (people per sq. km of land area)
# Mobile cellular subscriptions (per 100 people)
# Telephone lines (per 100 people)
# Individuals using the Internet (% of population)
# GDP growth (annual %)
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)
# Employment in agriculture, male (% of male employment) (modeled ILO estimate)
# Employment in agriculture (% of total employment) (modeled ILO estimate)
# Employers, female (% of female employment) (modeled ILO estimate)
# Employers, male (% of male employment) (modeled ILO estimate)
# Employers, total (% of total employment) (modeled ILO estimate)
# Own-account workers, female (% of female employment) (modeled ILO estimate)
# Own-account workers, male (% of male employment) (modeled ILO estimate)
# Own-account workers, total (% of male employment) (modeled ILO estimate)
# Self-employed, female (% of female employment) (modeled ILO estimate)
# Self-employed, male (% of male employment) (modeled ILO estimate)
# Self-employed, total (% of total employment) (modeled ILO estimate)
# Total employment, total (ages 15+)
# Vulnerable employment, female (% of female employment) (modeled ILO estimate)
# Vulnerable employment, male (% of male employment) (modeled ILO estimate)
# Vulnerable employment, total (% of total employment) (modeled ILO estimate)
# Wage and salaried workers, female (% of female employment) (modeled ILO estimate)
# Wage and salaried workers, male (% of male employment) (modeled ILO estimate)
# Wage and salaried workers, total (% of total employment) (modeled ILO estimate)
# Contributing family workers, female (% of female employment) (modeled ILO estimate)
# Contributing family workers, male (% of male employment) (modeled ILO estimate)
# Contributing family workers, total (% of total employment) (modeled ILO estimate)
# Employment in industry, female (% of female employment) (modeled ILO estimate)
# Employment in industry, male (% of male employment) (modeled ILO estimate)
# Employment in industry (% of total employment) (modeled ILO estimate)
# Employment in services, female (% of female employment) (modeled ILO estimate)
# Employment in services, male (% of male employment) (modeled ILO estimate)
# Employment in services (% of total employment) (modeled ILO estimate)
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)
# Labor force, total
# Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)
# Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)
# Unemployment, female (% of female labor force) (modeled ILO estimate)
# Unemployment, male (% of male labor force) (modeled ILO estimate)
# Unemployment, total (% of total labor force) (modeled ILO estimate)
# Adolescent fertility rate (births per 1,000 women ages 15-19)
# Life expectancy at birth, female (years)
# Life expectancy at birth, male (years)
# Fertility rate, total (births per woman)
# Population ages 0-14, total
# Population ages 0-14 (% of total)
# Population ages 15-64, total
# Population ages 15-64 (% of total)
# Population ages 65 and above, total
# Population ages 65 and above (% of total)
# Age dependency ratio (% of working-age population)
# Population growth (annual %)
# Population, total
# Rural population
# Rural population (% of total population)
# Urban population
# Urban population (% of total)

# %% [markdown]
# # 3

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df[df['Country Name'] == 'France'][0:1]
# Out:
#        index Country Name Country Code  \
# 11288  11288       France          FRA
#
#                                    Series Name     Series Code 2016 [YR2016]
# 11288  Access to electricity (% of population)  EG.ELC.ACCS.ZS           100

# %%
dropped_pivot.reset_index()
# Out:
# Series Code Country Code BX.KLT.DINV.WD.GD.ZS    EG.ELC.ACCS.ZS  \
# 0                    AFG    0.480709517928724  84.1371383666992
# 1                    ALB     8.78673446886916               100
# 2                    ARE     2.51668651639507               100
# 3                    ARG    0.587564212452168               100
# 4                    ARM     3.20605773747274               100
# ..                   ...                  ...               ...
# 153                  WSM    0.321022637394075               100
# 154                  YEM    -3.08016185948595  71.6423492431641
# 155                  ZAF    0.749015048767685              84.2
# 156                  ZMB     3.16307184259788  27.2193374633789
# 157                  ZWE     2.06386661053657  38.1451377868652
#
# Series Code       EN.POP.DNST    IT.CEL.SETS.P2     IT.MLT.MAIN.P2  \
# 0            53.0834053242655  62.3354168186364  0.329501080793093
# 1            104.967189781022  115.152264870754   8.49659712378705
# 2            110.880526315789  214.734910155894   24.6591658852604
# 3            16.0220668033281  145.330506257721   22.6663911659133
# 4            102.733263083948  117.428480971111   18.1763228866363
# ..                        ...               ...                ...
# 153          68.9487632508834  77.3903907751441   4.96040999359385
# 154          52.2457961626608  59.5741303186718   4.22643198122056
# 155          46.1758591695587  147.125205923013   8.07428690283487
# 156          22.3185541909361  72.4293383495898  0.611202557471074
# 157          41.7483830942226  79.7438843785669   1.89296066552564
#
# Series Code    IT.NET.USER.ZS  NY.GDP.MKTP.KD.ZG   SL.AGR.EMPL.FE.ZS  \
# 0            10.5957264186601   2.36671191565063    72.6210021972656
# 1             66.363444701023   3.35215921082479    47.2719993591309
# 2            90.6000073180483   2.98844182081464  0.0130000002682209
# 3            70.9689808206024  -1.82254217028903   0.172000005841255
# 4            64.3460297653742  0.199999997770945    38.3429985046387
# ..                        ...                ...                 ...
# 153          29.4117301129981   7.14516885471595    3.26200008392334
# 154          24.5792083636211   -34.339754357643    57.2430000305176
# 155                        54  0.565362939110358    3.89599990844727
# 156          25.5065788475702   3.75717780476374    62.8650016784668
# 157               23.11998904  0.615713754356918    71.7710037231445
#
# Series Code  SL.AGR.EMPL.MA.ZS  ... SP.POP.1564.TO.ZS SP.POP.65UP.TO  \
# 0             59.1220016479492  ...  53.5989174986911         880803
# 1             35.8059997558594  ...  69.4436888572377         369116
# 2            0.186000004410744  ...  85.0281004210317         100499
# 3            0.808000028133392  ...  63.8805193371653        4849887
# 4             30.4489994049072  ...  69.0155209763623         323610
# ..                         ...  ...               ...            ...
# 153           6.14200019836426  ...  57.6784112748239          10658
# 154           34.3880004882813  ...  56.8504274528333         797863
# 155           6.88100004196167  ...  65.6131047933845        2918033
# 156           44.6969985961914  ...  52.4164883111059         413421
# 157            63.117000579834  ...  55.8050339676597         454722
#
# Series Code SP.POP.65UP.TO.ZS       SP.POP.DPND         SP.POP.GROW  \
# 0            2.54155755627188  86.5709321507136     2.6891634730922
# 1             12.833914490006  44.0015401014685  -0.159880412127734
# 2            1.08417698604861  17.6081783608388    1.25175905246942
# 3            11.0608238612845  56.5422464275751   0.984741905647839
# 4            11.0642857533602  44.8949433189816   0.269302288175516
# ..                        ...               ...                 ...
# 153          5.46213965406791  73.3750944066818   0.702526006807934
# 154          2.89246243856948  75.9001725764795    2.45150204297636
# 155          5.20933385673633  52.4085780041956    1.30137401321457
# 156          2.49178037524282  90.7796634648112    3.00281551523404
# 157          2.81555298884322  79.1953035239659     2.3360695495183
#
# Series Code SP.POP.TOTL SP.RUR.TOTL SP.RUR.TOTL.ZS SP.URB.TOTL  \
# 0              34656032    25985093          74.98     8670939
# 1               2876101     1195854         41.579     1680247
# 2               9269612     1300990         14.035     7968622
# 3              43847430     3671345          8.373    40176085
# 4               2924816     1079784         36.918     1845032
# ..                  ...         ...            ...         ...
# 153              195125      158674         81.319       36451
# 154            27584213    17821057         64.606     9763156
# 155            56015473    19414403         34.659    36601070
# 156            16591390     9550336         57.562     7041054
# 157            16150362    10934441         67.704     5215921
#
# Series Code SP.URB.TOTL.IN.ZS
# 0                       25.02
# 1                      58.421
# 2                      85.965
# 3                      91.627
# 4                      63.082
# ..                        ...
# 153                    18.681
# 154                    35.394
# 155                    65.341
# 156                    42.438
# 157                    32.296
#
# [158 rows x 63 columns]

# %%
print(dropped_pivot.reset_index()[dropped_pivot.index == 'GRC'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'HUN'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'FRA'].index)
# Out:
# Int64Index([56], dtype='int64')
# Int64Index([62], dtype='int64')
# Int64Index([49], dtype='int64')

# %%
# scale before PCA
pca = PCA(n_components=3)
scalePivot  = StandardScaler().fit_transform(dropped_pivot.T) #standardising the data, rescaling
Scaled_PCA = pca.fit_transform(scalePivot)
noScale_PCA = pca.fit_transform(dropped_pivot.T)

# %%
print(np.shape(noScale_PCA))
print(np.shape(Scaled_PCA))
# Out:
# (62, 3)
# (62, 3)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,
                                  sharex=False,
                                  sharey=False,
                                  figsize=(10,8))
ax1.plot(noScale_PCA[:,0],noScale_PCA[:,1],'*')
ax1.set_xlabel('PCA 1', fontsize=15)
ax1.set_ylabel('PCA 2', fontsize=15)
ax2.plot(noScale_PCA[:,0],noScale_PCA[:,2],'o')
ax2.set_xlabel('PCA 1', fontsize=15)
ax2.set_ylabel('PCA 3', fontsize=15)
ax3.plot(noScale_PCA[:,1],noScale_PCA[:,2],'x')
ax3.set_xlabel('PCA 2', fontsize=15)
ax3.set_ylabel('PCA 3', fontsize=15)
fig.suptitle('Non-scaled PCA plots', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Non-scaled PCA plots')

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,
                                  sharex=True,
                                  sharey=True,
                                  figsize=(10,8))
ax1.plot(Scaled_PCA[:,0],Scaled_PCA[:,1],'*')
ax1.set_xlabel('PCA 1', fontsize=15)
ax1.set_ylabel('PCA 2', fontsize=15)
ax2.plot(Scaled_PCA[:,0],Scaled_PCA[:,2],'o')
ax2.set_xlabel('PCA 1', fontsize=15)
ax2.set_ylabel('PCA 3', fontsize=15)
ax3.plot(Scaled_PCA[:,1],Scaled_PCA[:,2],'x')
ax3.set_xlabel('PCA 2', fontsize=15)
ax3.set_ylabel('PCA 3', fontsize=15)
fig.suptitle('Scaled PCA plots', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scaled PCA plots')

# %%
principalDf = pd.DataFrame(data = Scaled_PCA, columns = ['principal component 1', 'principal component 2','principal component 3'])
principalDf.insert(loc=0,column='Series Code', value=dropped_pivot.T.index)

# %%
principalDf.sort_values(by=['principal component 2'], ascending=False)
# Out:
#        Series Code  principal component 1  principal component 2  \
# 58     SP.RUR.TOTL              22.738931              15.382282
# 49  SP.POP.0014.TO              13.755345               5.568553
# 57     SP.POP.TOTL              61.510193               2.293035
# 59  SP.RUR.TOTL.ZS              -4.098190              -0.065073
# 45     SP.ADO.TFRT              -4.098267              -0.065547
# ..             ...                    ...                    ...
# 51  SP.POP.1564.TO              37.853633              -1.215180
# 19     SL.EMP.TOTL              23.394046              -1.519950
# 38  SL.TLF.TOTL.IN              25.673954              -1.584242
# 53  SP.POP.65UP.TO               1.702189              -2.192327
# 60     SP.URB.TOTL              34.671749             -13.155241
#
#     principal component 3
# 58              -0.760704
# 49               4.496460
# 57               1.736689
# 59               0.038671
# 45               0.039339
# ..                    ...
# 51              -1.228159
# 19              -3.758887
# 38              -3.655823
# 53              -1.453724
# 60               2.536338
#
# [62 rows x 4 columns]

# %%
df[df['Series Code'] == principalDf.sort_values(by=['principal component 2'], ascending=False).values[0,0]].sort_values(by=['2016 [YR2016]'], ascending=False).values[0,3]
# Out:
# 'Rural population'

# %%
principalDf.sort_values(by=['principal component 1'], ascending=False)
# Out:
#           Series Code  principal component 1  principal component 2  \
# 57        SP.POP.TOTL              61.510193               2.293035
# 51     SP.POP.1564.TO              37.853633              -1.215180
# 60        SP.URB.TOTL              34.671749             -13.155241
# 38     SL.TLF.TOTL.IN              25.673954              -1.584242
# 19        SL.EMP.TOTL              23.394046              -1.519950
# ..                ...                    ...                    ...
# 6   NY.GDP.MKTP.KD.ZG              -4.099431              -0.065967
# 27  SL.FAM.WORK.MA.ZS              -4.099436              -0.065955
# 48     SP.DYN.TFRT.IN              -4.099438              -0.065971
# 10  SL.EMP.MPYR.FE.ZS              -4.099448              -0.065972
# 56        SP.POP.GROW              -4.099477              -0.065996
#
#     principal component 3
# 57               1.736689
# 51              -1.228159
# 60               2.536338
# 38              -3.655823
# 19              -3.758887
# ..                    ...
# 6                0.038964
# 27               0.038947
# 48               0.038972
# 10               0.038933
# 56               0.038958
#
# [62 rows x 4 columns]

# %% [markdown]
# # 4

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)

# %%
scalePivot_orig  = StandardScaler().fit_transform(dropped_pivot) #standardising the data, rescaling
Scaled_TSNE = tsne.fit_transform(scalePivot_orig)

# %%
print(dropped_pivot.reset_index()[dropped_pivot.index == 'GRC'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'HUN'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'CHN'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'NOR'].index)
print(dropped_pivot.reset_index()[dropped_pivot.index == 'RUS'].index)
# Out:
# Int64Index([56], dtype='int64')
# Int64Index([62], dtype='int64')
# Int64Index([28], dtype='int64')
# Int64Index([109], dtype='int64')
# Int64Index([123], dtype='int64')

# %%
plt.figure(figsize=(30, 20))
plt.plot(Scaled_TSNE[:,0],Scaled_TSNE[:,1],'o', markersize=10)
for i in range(np.shape(dropped_pivot.index[:])[0]):
    if(np.any(dropped_pivot.index[i] == np.array(['GRC','RUS', 'NOR', 'CHN', 'HUN']))):
        plt.annotate(dropped_pivot.index[i],
                 (Scaled_TSNE[i,0], Scaled_TSNE[i,1]),
                fontsize=20,
                    color='red')
    else:
            plt.annotate(dropped_pivot.index[i],
             (Scaled_TSNE[i,0], Scaled_TSNE[i,1]),
            fontsize=20)
plt.xlabel('T-SNE 1', fontsize=30)
plt.ylabel('T-SNE 2', fontsize=30)
# Out:
# Text(0, 0.5, 'T-SNE 2')

# %% [markdown]
# # 5

# %%
from sklearn.cluster import KMeans
import seaborn as sns

# %%
sns.clustermap(scalePivot_orig, cmap = 'gist_heat')

# %%
np.shape(scalePivot.T)
# Out:
# (158, 62)

# %%
k_Df = pd.DataFrame(data = scalePivot_orig, columns = dropped_pivot.columns,)

# %%
k_Df
# Out:
# Series Code  BX.KLT.DINV.WD.GD.ZS  EG.ELC.ACCS.ZS  EN.POP.DNST  \
# 0                       -0.481803        0.015091    -0.179843
# 1                        0.492033        0.601137    -0.150997
# 2                       -0.243096        0.601137    -0.147710
# 3                       -0.469275        0.601137    -0.200448
# 4                       -0.162271        0.601137    -0.152239
# ..                            ...             ...          ...
# 153                     -0.500526        0.601137    -0.171023
# 154                     -0.899296       -0.446523    -0.180309
# 155                     -0.450346        0.017413    -0.183684
# 156                     -0.167311       -2.087712    -0.196948
# 157                     -0.296187       -1.684063    -0.186145
#
# Series Code  IT.CEL.SETS.P2  IT.MLT.MAIN.P2  IT.NET.USER.ZS  \
# 0                 -1.283053       -1.045661       -1.527584
# 1                  0.081131       -0.529440        0.493921
# 2                  2.653208        0.492152        1.372464
# 3                  0.860591        0.366194        0.660865
# 4                  0.139922        0.082389        0.420792
# ..                      ...             ...             ...
# 153               -0.894204       -0.752953       -0.845529
# 154               -1.354373       -0.799346       -1.020702
# 155                0.906946       -0.556134        0.045763
# 156               -1.022341       -1.027855       -0.987086
# 157               -0.833417       -0.946839       -1.073596
#
# Series Code  NY.GDP.MKTP.KD.ZG  SL.AGR.EMPL.FE.ZS  SL.AGR.EMPL.MA.ZS  \
# 0                    -0.118411           1.705807           1.465333
# 1                     0.120981           0.799799           0.445796
# 2                     0.032624          -0.889304          -1.111757
# 3                    -1.136094          -0.883621          -1.084559
# 4                    -0.644764           0.480664           0.211551
# ..                         ...                ...                ...
# 153                   1.042405          -0.773180          -0.851320
# 154                  -9.035402           1.156176           0.383791
# 155                  -0.556007          -0.750520          -0.819005
# 156                   0.219371           1.357114           0.834572
# 157                  -0.543776           1.675427           1.640022
#
# Series Code  SL.AGR.EMPL.ZS  ...  SP.POP.1564.TO.ZS  SP.POP.65UP.TO  \
# 0                  1.475828  ...          -1.545123       -0.221700
# 1                  0.630956  ...           0.787284       -0.259409
# 2                 -1.022568  ...           3.081365       -0.279205
# 3                 -1.006806  ...          -0.031634        0.070803
# 4                  0.361119  ...           0.724256       -0.262763
# ..                      ...  ...                ...             ...
# 153               -0.820722  ...          -0.944607       -0.285826
# 154                0.439155  ...          -1.066489       -0.227813
# 155               -0.801325  ...           0.223408       -0.071566
# 156                1.148006  ...          -1.719181       -0.256144
# 157                1.724144  ...          -1.220375       -0.253100
#
# Series Code  SP.POP.65UP.TO.ZS  SP.POP.DPND  SP.POP.GROW  SP.POP.TOTL  \
# 0                    -1.023992     1.626397     1.164675    -0.067772
# 1                     0.634731    -0.785676    -1.363441    -0.271893
# 2                    -1.258865    -2.281180    -0.110814    -0.230828
# 3                     0.348979    -0.075093    -0.347753    -0.008737
# 4                     0.349536    -0.735054    -0.982603    -0.271580
# ..                         ...          ...          ...          ...
# 153                  -0.553309     0.878692    -0.598179    -0.289113
# 154                  -0.967440     1.021769     0.953785    -0.113194
# 155                  -0.594052    -0.309315    -0.066788     0.069418
# 156                  -1.032014     1.864872     1.442996    -0.183800
# 157                  -0.979835     1.208478     0.851355    -0.186633
#
# Series Code  SP.RUR.TOTL  SP.RUR.TOTL.ZS  SP.URB.TOTL  SP.URB.TOTL.IN.ZS
# 0               0.061437        1.519470    -0.206368          -1.519470
# 1              -0.227753        0.049564    -0.297572          -0.049564
# 2              -0.226527       -1.162589    -0.215531           1.162589
# 3              -0.198875       -1.411761     0.204663           1.411761
# 4              -0.229108       -0.155557    -0.295422           0.155557
# ..                   ...             ...          ...                ...
# 153            -0.239853        1.798436    -0.319018          -1.798436
# 154            -0.033805        1.062933    -0.192119          -1.062933
# 155            -0.015217       -0.254971     0.158021           0.254971
# 156            -0.130290        0.752941    -0.227632          -0.752941
# 157            -0.114144        1.199269    -0.251444          -1.199269
#
# [158 rows x 62 columns]

# %%
k_Df.insert(loc=0,column='Country Code', value=dropped_pivot.index)

# %%
k_Df = k_Df.reset_index(drop=True)

# %%
km = KMeans(n_clusters=4)

# %%
fit_km = km.fit(scalePivot_orig)

# %%
x_kmeans = km.fit_predict(scalePivot_orig)

plt.subplot(1,2,1)
for i in [0,1,2]:
    plt.plot(scalePivot_orig[x_kmeans==i,0],scalePivot_orig[x_kmeans==i,1],'o', label=str(i)+'. cluster')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.legend()
